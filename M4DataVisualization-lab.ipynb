# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2024-03-21 11:01:36--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104, 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite.9’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  38.1MB/s    in 0.9s
#
# 2024-03-21 11:01:38 (38.1 MB/s) - ‘m4_survey_data.sqlite.9’ saved [36679680/36679680]

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here
df = pd.read_sql_query("SELECT * FROM master", conn)
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with a column named 'ConvertedComp'
# Drop missing values from the 'ConvertedComp' column
df_cleaned = df.dropna(subset=['ConvertedComp'])

# Plot the histogram
plt.figure(figsize=(10, 6))
plt.hist(df_cleaned['ConvertedComp'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of Converted Compensation')
plt.xlabel('Converted Compensation (USD)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here

import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with a column named 'Age'
# Drop missing values from the 'Age' column
df_cleaned = df.dropna(subset=['Age'])

# Plot the box plot
plt.figure(figsize=(8, 6))
plt.boxplot(df_cleaned['Age'])
plt.title('Box plot of Age')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# your code goes here

import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with columns 'Age' and 'WorkWeekHrs'
# Drop missing values from the 'Age' and 'WorkWeekHrs' columns
df_cleaned = df.dropna(subset=['Age', 'WorkWeekHrs'])

# Plot the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df_cleaned['Age'], df_cleaned['WorkWeekHrs'], color='skyblue', alpha=0.6)
plt.title('Scatter Plot of Age and WorkWeekHrs')
plt.xlabel('Age')
plt.ylabel('WorkWeekHrs')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with columns 'WorkWeekHrs', 'CodeRevHrs', and 'Age'
# Drop missing values from the 'WorkWeekHrs', 'CodeRevHrs', and 'Age' columns
df_cleaned = df.dropna(subset=['WorkWeekHrs', 'CodeRevHrs', 'Age'])

# Set the bubble size based on the 'Age' column
bubble_size = df_cleaned['Age'] * 10  # Adjust the multiplier as needed for better visualization

# Plot the bubble plot
plt.figure(figsize=(10, 8))
plt.scatter(df_cleaned['WorkWeekHrs'], df_cleaned['CodeRevHrs'], s=bubble_size, color='skyblue', alpha=0.6)
plt.title('Bubble Plot of WorkWeekHrs and CodeRevHrs')
plt.xlabel('WorkWeekHrs')
plt.ylabel('CodeRevHrs')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
QUERY="""
select *
from DatabaseDesireNextYear
"""
df2 = pd.read_sql_query(QUERY,conn)
df2
df3=pd.DataFrame(df2["DatabaseDesireNextYear"].value_counts(),columns=['DatabaseDesireNextYear'])
df3.head()
# Out:
#                DatabaseDesireNextYear
# PostgreSQL                       4328
# MongoDB                          3649
# Redis                            3331
# MySQL                            3281
# Elasticsearch                    2856

# %%
# your code goes here
QUERY="""
select *
from DatabaseDesireNextYear
"""
df2 = pd.read_sql_query(QUERY,conn)
df2
#df3=pd.DataFrame(df2["DatabaseDesireNextYear"].value_counts(),columns=['DatabaseDesireNextYear'])
#df3.head()
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df2' with a column named 'DatabaseDesireNextYear'

# Extract information about desired databases and stack them into a Series
database_series = df2['DatabaseDesireNextYear'].str.split('; ').apply(pd.Series).stack()

# Count occurrences of each database
database_counts = database_series.value_counts()

# Select the top 5 databases
top_databases = database_counts.head(5)

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_databases, labels=top_databases.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Databases Respondents Wish to Learn Next Year')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
QUERY = """
SELECT LanguageWorkedWith, count(Respondent) as count
from LanguageWorkedWith  where LanguageWorkedWith = 'SQL'
"""
df=pd.read_sql_query(QUERY,conn)
print(df)
# Out:
#   LanguageWorkedWith  count
# 0                SQL   7106

# %%
QUERY = """ SELECT * FROM DatabaseWorkedWith """

df = pd.read_sql_query(QUERY, conn)
print(df)
# Remove duplicates in the 'Respondent' column while keeping all occurrences
df_unique = df.drop_duplicates(subset=['Respondent'], keep=False)

# Filter rows where 'DatabaseWorkedWith' is 'MySQL'
mysql_df = df_unique[df_unique['DatabaseWorkedWith'] == 'MySQL']

# Count the occurrences of 'MySQL' for each respondent
mysql_counts = mysql_df['Respondent'].value_counts()


# Filter out respondents who worked on 'MySQL' only
mysql_only_counts = mysql_counts[mysql_counts == 1]

# Print the count of respondents who worked on 'MySQL' only
print("Number of respondents who worked on 'MySQL' only:", len(mysql_only_counts))
# Out:
#        Respondent    DatabaseWorkedWith
# 0               4                 MySQL
# 1               4                SQLite
# 2               9              DynamoDB
# 3               9            PostgreSQL
# 4               9                SQLite
# ...           ...                   ...
# 31370       25137                 MySQL
# 31371       25138            PostgreSQL
# 31372       25141  Microsoft SQL Server
# 31373       25141                 Redis
# 31374       25142            PostgreSQL
#
# [31375 rows x 2 columns]
# Number of respondents who worked on 'MySQL' only: 474

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# your code goes here

import matplotlib.pyplot as plt
QUERY = """ SELECT Age,WorkWeekHrs,CodeRevHRs FROM master
"""
df = pd.read_sql_query(QUERY,conn)
# Assuming you have a DataFrame named 'df' with columns 'Age', 'WorkWeekHrs', and 'CodeRevHrs'
# Filter the DataFrame for respondents in the age group 30 to 35
age_group_df = df[(df['Age'] >= 30) & (df['Age'] <= 35)]

# Calculate median 'WorkWeekHrs' and 'CodeRevHrs' for the age group
median_work_week_hrs = age_group_df['WorkWeekHrs'].median()
median_code_rev_hrs = age_group_df['CodeRevHrs'].median()

# Plot the stacked chart
plt.figure(figsize=(10, 6))
plt.bar('Age Group(30-35)', median_work_week_hrs, label='Median WorkWeekHrs')
plt.bar('Age Group(30-35)', median_code_rev_hrs, bottom=median_work_week_hrs, label='Median CodeRevHrs')
plt.title('Stacked Chart of Median WorkWeekHrs and CodeRevHrs (Age Group 30-35)')
plt.xlabel('Age Group')
plt.ylabel('Median Hours')
plt.legend()
plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
# your code goes here
QUERY = """ SELECT * FROM master """
df = pd.read_sql_query(QUERY,conn)
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with columns 'Age' and 'ConvertedComp'

# Filter the DataFrame for respondents aged 45 to 60
filtered_df = df[(df['Age'] >= 45) & (df['Age'] <= 60)]

# Group the filtered DataFrame by the 'Age' column and calculate the median 'ConvertedComp'
median_comp_by_age = filtered_df.groupby('Age')['ConvertedComp'].median()

# Plot the median 'ConvertedComp' values
plt.figure(figsize=(10, 6))
median_comp_by_age.plot(kind='line', color='skyblue')
plt.title('Median ConvertedComp for Ages 45 to 60')
plt.xlabel('Age')
plt.ylabel('Median ConvertedComp')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter the DataFrame for respondents aged 25 to 30
filtered_df = df[(df['Age'] >= 25) & (df['Age'] <= 30)]

# Group the filtered DataFrame by Age and calculate the median ConvertedComp
median_comp_by_age = filtered_df.groupby('Age')['ConvertedComp'].median()

# Plot Age vs median ConvertedComp as a line chart
plt.figure(figsize=(10, 6))
plt.plot(median_comp_by_age.index, median_comp_by_age.values, marker='o', color='skyblue', linestyle='-')
plt.title('Median ConvertedComp for Ages 25-30')
plt.xlabel('Age')
plt.ylabel('Median ConvertedComp')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here
import matplotlib.pyplot as plt

# Count the occurrences of each category in the 'MainBranch' column
branch_counts = df['MainBranch'].value_counts()

# Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
branch_counts.plot(kind='barh', color='skyblue')
plt.title('Distribution of Main Branches')
plt.xlabel('Count')
plt.ylabel('Main Branch')
plt.grid(axis='x')
plt.tight_layout()
plt.show()

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
